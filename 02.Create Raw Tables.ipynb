# %%
products_df = spark.read.option("header","true").csv("/Volumes/novacart/landing/operational/Products.csv")
products_df.writeTo("novacart.raw.products").createOrReplace()

# %%
orders_df = spark.read.option("header","true").csv("/Volumes/novacart/landing/operational/Orders.csv")
orders_df.writeTo("novacart.raw.orders").createOrReplace()

# %%
payments_df = spark.read.option("header","true").csv("/Volumes/novacart/landing/operational/Payments.csv")
payments_df.writeTo("novacart.raw.payments").createOrReplace()
